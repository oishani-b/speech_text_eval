# %%
# all imports
import pandas as pd
import csv
import os
from pydub import AudioSegment

# %%
def read_and_clean_session_results(session_file_name):
    
    # Read the csv file with session data from session file name, 
    # relevant file will be called results.csv
    # Example file path input:
    # '/Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data'
    results_file_name = os.path.join(session_file_name, 'results.csv')
    df = pd.read_csv(results_file_name)

    # Dropping irrelevant columns for analysis
    df.drop(['expt_id', 'group_id', 'network_error_repeat', 'participation_duration', 'response_correct', 'response_mode', 'response_rt', 'response_target', 'session_start_time', 'trial_duration', 'trial_num', 'trial_template'], axis='columns')

    # Re-order columns for better readability
    clean_df = df[['session_id', 'participant_id', 'stimuli_presented', 'response_type', 'response_name', 'response_value']]

    # Return cleaned dataframe
    return clean_df

# Test run
df = read_and_clean_session_results('/Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data')
df
# Out:
#                    session_id  \
# 0    67d94e1a42f12a9364065df2
# 1    67d94e1a42f12a9364065df2
# 2    67d94e1a42f12a9364065df2
# 3    67d94e1a42f12a9364065df2
# 4    67d94e1a42f12a9364065df2
# ..                        ...
# 250  67d94e1a42f12a9364065df2
# 251  67d94e1a42f12a9364065df2
# 252  67d94e1a42f12a9364065df2
# 253  67d94e1a42f12a9364065df2
# 254  67d94e1a42f12a9364065df2
#
#                                         participant_id stimuli_presented  \
# 0    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ1
# 1    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...      LangBgQOther
# 2    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ2
# 3    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...      LangBgQOther
# 4    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ3
# ..                                                 ...               ...
# 250  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt39
# 251  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt22
# 252  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt29
# 253  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt27
# 254  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       FinalPrompt
#
#        response_type      response_name  \
# 0    choice-response  LangBgOptionsResp
# 1      text-response    LangBgOtherResp
# 2    choice-response  LangBgOptionsResp
# 3      text-response    LangBgOtherResp
# 4    choice-response  LangBgOptionsResp
# ..               ...                ...
# 250   audio-response    LocPromptResp39
# 251   audio-response    LocPromptResp22
# 252   audio-response    LocPromptResp29
# 253   audio-response    LocPromptResp27
# 254    text-response          FinalResp
#
#                                       response_value
# 0      ['Other (you may specify in the next slide)']
# 1                                    Korean, Spanish
# 2      ['Other (you may specify in the next slide)']
# 3                                             Korean
# 4                           ['None besides English']
# ..                                               ...
# 250  53c7dbc41f259d6f7157d364-81-LocPromptResp39.mp4
# 251  53c7dbc41f259d6f7157d364-82-LocPromptResp22.mp4
# 252  53c7dbc41f259d6f7157d364-83-LocPromptResp29.mp4
# 253  53c7dbc41f259d6f7157d364-84-LocPromptResp27.mp4
# 254                                              NaN
#
# [255 rows x 6 columns]

# %%
def add_lang_bg_3(df):

    # first, we make a filter with the stimuli being LangBgQ3
    lang_bg_q3_filtered = df[df.loc[:, 'stimuli_presented'] == 'LangBgQ3']
    lang_bg_q3_filtered
    
    # next, we set the index to be participant_id for the mapping
    lang_bg_q3_indexed = lang_bg_q3_filtered.set_index('participant_id')
    lang_bg_q3_indexed
    
    
    # then, we get out the 'response_value' column for the mapping
    lang_bg_q3_map = lang_bg_q3_indexed['response_value']
    lang_bg_q3_map
    
    # then, we use the map function 
    df.loc[:, 'lang_bg_q3_resp'] = df.loc[:, 'participant_id'].map(lang_bg_q3_map)
    df
    
    # next, we're going to add a column for lang_bg_q3_english_only as a binary encoder
    df.loc[:, 'lang_bg_q3_english_only'] = df.loc[:, 'lang_bg_q3_resp'].apply(lambda x: isinstance(x, str) and 'None besides English' in x)
    df

    return df

# Test run
df = add_lang_bg_3(df)
df
# Out:
#                    session_id  \
# 0    67d94e1a42f12a9364065df2
# 1    67d94e1a42f12a9364065df2
# 2    67d94e1a42f12a9364065df2
# 3    67d94e1a42f12a9364065df2
# 4    67d94e1a42f12a9364065df2
# ..                        ...
# 250  67d94e1a42f12a9364065df2
# 251  67d94e1a42f12a9364065df2
# 252  67d94e1a42f12a9364065df2
# 253  67d94e1a42f12a9364065df2
# 254  67d94e1a42f12a9364065df2
#
#                                         participant_id stimuli_presented  \
# 0    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ1
# 1    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...      LangBgQOther
# 2    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ2
# 3    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...      LangBgQOther
# 4    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ3
# ..                                                 ...               ...
# 250  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt39
# 251  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt22
# 252  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt29
# 253  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt27
# 254  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       FinalPrompt
#
#        response_type      response_name  \
# 0    choice-response  LangBgOptionsResp
# 1      text-response    LangBgOtherResp
# 2    choice-response  LangBgOptionsResp
# 3      text-response    LangBgOtherResp
# 4    choice-response  LangBgOptionsResp
# ..               ...                ...
# 250   audio-response    LocPromptResp39
# 251   audio-response    LocPromptResp22
# 252   audio-response    LocPromptResp29
# 253   audio-response    LocPromptResp27
# 254    text-response          FinalResp
#
#                                       response_value  \
# 0      ['Other (you may specify in the next slide)']
# 1                                    Korean, Spanish
# 2      ['Other (you may specify in the next slide)']
# 3                                             Korean
# 4                           ['None besides English']
# ..                                               ...
# 250  53c7dbc41f259d6f7157d364-81-LocPromptResp39.mp4
# 251  53c7dbc41f259d6f7157d364-82-LocPromptResp22.mp4
# 252  53c7dbc41f259d6f7157d364-83-LocPromptResp29.mp4
# 253  53c7dbc41f259d6f7157d364-84-LocPromptResp27.mp4
# 254                                              NaN
#
#                                    lang_bg_q3_resp  lang_bg_q3_english_only
# 0                         ['None besides English']                     True
# 1                         ['None besides English']                     True
# 2                         ['None besides English']                     True
# 3                         ['None besides English']                     True
# 4                         ['None besides English']                     True
# ..                                             ...                      ...
# 250  ['Other (you may specify in the next slide)']                    False
# 251  ['Other (you may specify in the next slide)']                    False
# 252  ['Other (you may specify in the next slide)']                    False
# 253  ['Other (you may specify in the next slide)']                    False
# 254  ['Other (you may specify in the next slide)']                    False
#
# [255 rows x 8 columns]

# %%
def add_prompts_from_stimulus_definitions(df):

    # read in stimulus definitions file
    stimulus_definitions = pd.read_csv('/Users/oishanibandopadhyay/Documents/Revising Honors Project/stimulus-definitions.csv')

    # drop irrelevant type column
    stimulus_definitions = stimulus_definitions.drop(['type'], axis='columns')

    # reorder and rename columns and set name as the index to later merge
    stimulus_definitions = stimulus_definitions[['name', 'content']]
    stimulus_definitions = stimulus_definitions.set_index('name')
    stimulus_definitions = stimulus_definitions.rename(columns = {'content': 'prompt_text'})

    # merge prompt_name column to the df
    df = df.merge(stimulus_definitions, left_on = 'stimuli_presented', right_index = True, how = 'left')

    return df

# Test run
df = add_prompts_from_stimulus_definitions(df)
df
# Out:
#                    session_id  \
# 0    67d94e1a42f12a9364065df2
# 1    67d94e1a42f12a9364065df2
# 2    67d94e1a42f12a9364065df2
# 3    67d94e1a42f12a9364065df2
# 4    67d94e1a42f12a9364065df2
# ..                        ...
# 250  67d94e1a42f12a9364065df2
# 251  67d94e1a42f12a9364065df2
# 252  67d94e1a42f12a9364065df2
# 253  67d94e1a42f12a9364065df2
# 254  67d94e1a42f12a9364065df2
#
#                                         participant_id stimuli_presented  \
# 0    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ1
# 1    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...      LangBgQOther
# 2    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ2
# 3    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...      LangBgQOther
# 4    b5bdd1b55fdf1a07a1cc3907eb6ade997ee127e8708b58...          LangBgQ3
# ..                                                 ...               ...
# 250  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt39
# 251  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt22
# 252  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt29
# 253  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       LocPrompt27
# 254  9e4c7d9ba7377ea14d0e228c38df883deaf62f3f4d1837...       FinalPrompt
#
#        response_type      response_name  \
# 0    choice-response  LangBgOptionsResp
# 1      text-response    LangBgOtherResp
# 2    choice-response  LangBgOptionsResp
# 3      text-response    LangBgOtherResp
# 4    choice-response  LangBgOptionsResp
# ..               ...                ...
# 250   audio-response    LocPromptResp39
# 251   audio-response    LocPromptResp22
# 252   audio-response    LocPromptResp29
# 253   audio-response    LocPromptResp27
# 254    text-response          FinalResp
#
#                                       response_value  \
# 0      ['Other (you may specify in the next slide)']
# 1                                    Korean, Spanish
# 2      ['Other (you may specify in the next slide)']
# 3                                             Korean
# 4                           ['None besides English']
# ..                                               ...
# 250  53c7dbc41f259d6f7157d364-81-LocPromptResp39.mp4
# 251  53c7dbc41f259d6f7157d364-82-LocPromptResp22.mp4
# 252  53c7dbc41f259d6f7157d364-83-LocPromptResp29.mp4
# 253  53c7dbc41f259d6f7157d364-84-LocPromptResp27.mp4
# 254                                              NaN
#
#                                    lang_bg_q3_resp  lang_bg_q3_english_only  \
# 0                         ['None besides English']                     True
# 1                         ['None besides English']                     True
# 2                         ['None besides English']                     True
# 3                         ['None besides English']                     True
# 4                         ['None besides English']                     True
# ..                                             ...                      ...
# 250  ['Other (you may specify in the next slide)']                    False
# 251  ['Other (you may specify in the next slide)']                    False
# 252  ['Other (you may specify in the next slide)']                    False
# 253  ['Other (you may specify in the next slide)']                    False
# 254  ['Other (you may specify in the next slide)']                    False
#
#                                            prompt_text
# 0    Which languages, if any, do you speak besides ...
# 1    If you selected Other, please name the other l...
# 2    Which languages were spoken around you where y...
# 3    If you selected Other, please name the other l...
# 4    Which languages do you think have an influence...
# ..                                                 ...
# 250              She is leaving for Savannah tomorrow.
# 251  They knew where Anirudh would be on a Friday e...
# 252              She is leaving for Calcutta tomorrow.
# 253  Macha what are you doing, come off to the movi...
# 254  If you have any suggestions, questions or comm...
#
# [255 rows x 9 columns]

# %%
def session_audio_to_wav(session_name):

    # finding audio folder inside session-xyz_data folder, not the audio folder inside it
    input_audio_folder = os.path.join(session_name, 'audio')
    
    # creating new folder for output pre-processed wav files in session-xyz_data folder
    output_audio_folder = os.path.join(session_name, 'audio_wav')
    os.makedirs(output_audio_folder, exist_ok = True)
    
    # iterating through input audio folder
    for i in os.listdir(input_audio_folder):
        # each audio file's full input path
        #full_input_path = f'{input_audio_folder}/{i}'
        full_input_path = os.path.join(input_audio_folder, i)

        # check if file is empty or too small to be processed
        if os.path.getsize(full_input_path) < 1024:
            print(f'\n Input audio file too small or empty: {full_input_path} \n')
            continue

        # checking if the audio file ends with .wav already
        file_path_without_extension = os.path.splitext(i)[0]
        file_path_with_wav = '{output_folder}/{path}.wav'.format(
            output_folder = output_audio_folder,
            path = file_path_without_extension)

        if os.path.exists(file_path_with_wav):
            print(f'Wav converted file exists at: {file_path_with_wav}')

        # if .wav version of input file does not exist in audio_wav folder, make it
        else:
            try:
                # using AudioSegment from pydub to get the audio from the input file
                audio = AudioSegment.from_file(os.path.join(input_audio_folder, i))

                # covert all audio files to mono (accounts for earphone recordings
                # which can have stereo audio or more than one channel)
                audio.set_channels(1)
                
                # sending the audio file converted to wav to the previously named wav filepath
                audio.export(f'{file_path_with_wav}')
                print(f"Audio file converted successfully: \n {file_path_with_wav}")

            # handle errors with the files, printing only the last line of the error
            except Exception as e:
                print(f'Error converting {full_input_path}: {e}')

# Testing
session_audio_to_wav('/Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data')
# Out:
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-17-LocPromptResp31.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-48-ExpPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-58-DialPromptResp13.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-33-HardPromptResp11.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-17-LocPromptResp31.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-39-HardPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-31-DialPromptResp1.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-24-LocPromptResp6.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-58-DialPromptResp13.mp4
#
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-54-LocPromptResp41.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-68-LocPromptResp10.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-48-ExpPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-50-ExpPromptResp2.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-68-LocPromptResp10.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-69-LocPromptResp13.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-14-LocPromptResp18.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-69-LocPromptResp13.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-83-LocPromptResp29.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-79-ExpPromptResp9.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-14-LocPromptResp18.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-55-DialPromptResp8.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-76-LocPromptResp16.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-41-LocPromptResp30.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-25-HardPromptResp4.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-81-LocPromptResp39.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-76-LocPromptResp16.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-25-HardPromptResp4.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-81-LocPromptResp39.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-79-ExpPromptResp9.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-39-HardPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-39-HardPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-28-ExpPromptResp4.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-51-DialPromptResp11.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-17-LocPromptResp31.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-53-ExpPromptResp1.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-68-LocPromptResp10.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-31-DialPromptResp1.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-54-LocPromptResp41.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-31-DialPromptResp1.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-28-ExpPromptResp4.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-54-LocPromptResp41.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-55-DialPromptResp8.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-69-LocPromptResp13.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-83-LocPromptResp29.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-14-LocPromptResp18.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-60-HardPromptResp10.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-55-DialPromptResp8.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-15-ExpPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-83-LocPromptResp29.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-25-HardPromptResp4.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-41-LocPromptResp30.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-81-LocPromptResp39.mp4
#
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-76-LocPromptResp16.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-41-LocPromptResp30.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-15-ExpPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-26-DialPromptResp6.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-64-HardPromptResp3.mp4
#
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-56-LocPromptResp34.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-15-ExpPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-34-DialPromptResp12.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-66-LocPromptResp38.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-49-HardPromptResp8.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-67-LocPromptResp11.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-47-DialPromptResp10.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-28-ExpPromptResp4.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-37-HardPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-53-ExpPromptResp1.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-35-LocPromptResp17.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-46-DialPromptResp9.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-37-HardPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-35-LocPromptResp17.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-19-LocPromptResp26.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-29-HardPromptResp1.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-53-ExpPromptResp1.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-32-HardPromptResp2.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-72-DialPromptResp2.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-57-LocPromptResp19.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-75-DialPromptResp7.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-27-DialPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-29-HardPromptResp1.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-32-HardPromptResp2.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-36-LocPromptResp12.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-57-LocPromptResp19.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-79-ExpPromptResp9.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-26-DialPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-64-HardPromptResp3.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-56-LocPromptResp34.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-26-DialPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-64-HardPromptResp3.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-56-LocPromptResp34.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-49-HardPromptResp8.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-66-LocPromptResp38.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-67-LocPromptResp11.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-49-HardPromptResp8.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-66-LocPromptResp38.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-67-LocPromptResp11.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-35-LocPromptResp17.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-46-DialPromptResp9.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-19-LocPromptResp26.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-50-ExpPromptResp2.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-46-DialPromptResp9.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-48-ExpPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-19-LocPromptResp26.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-37-HardPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-24-LocPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-27-DialPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-72-DialPromptResp2.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-36-LocPromptResp12.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-57-LocPromptResp19.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-75-DialPromptResp7.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-50-ExpPromptResp2.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-27-DialPromptResp5.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-24-LocPromptResp6.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-29-HardPromptResp1.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-72-DialPromptResp2.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-32-HardPromptResp2.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-36-LocPromptResp12.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-75-DialPromptResp7.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-52-LocPromptResp14.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-77-LocPromptResp9.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-65-LocPromptResp20.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-52-LocPromptResp14.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-65-LocPromptResp20.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-13-DialPromptResp3.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-77-LocPromptResp9.mp4
#
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-13-DialPromptResp3.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-30-LocPromptResp24.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-12-ExpPromptResp10.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-47-DialPromptResp10.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-20-ExpPromptResp8.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-34-DialPromptResp12.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-30-LocPromptResp24.wav
# Wav converted file exists at: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-12-ExpPromptResp10.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-22-LocPromptResp40.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-34-DialPromptResp12.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-59-ExpPromptResp7.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-61-LocPromptResp23.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-47-DialPromptResp10.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-20-ExpPromptResp8.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-78-LocPromptResp37.mp4
#
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-52-LocPromptResp14.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-45-LocPromptResp7.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-65-LocPromptResp20.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-42-ExpPromptResp3.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-63-LocPromptResp4.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-38-LocPromptResp3.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-18-LocPromptResp1.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-45-LocPromptResp7.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-23-LocPromptResp2.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-42-ExpPromptResp3.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-18-LocPromptResp1.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-38-LocPromptResp3.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-13-DialPromptResp3.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-30-LocPromptResp24.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-12-ExpPromptResp10.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-78-LocPromptResp37.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-22-LocPromptResp40.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-61-LocPromptResp23.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-78-LocPromptResp37.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-22-LocPromptResp40.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-62-LocPromptResp8.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-43-LocPromptResp5.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-61-LocPromptResp23.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-62-LocPromptResp8.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-43-LocPromptResp5.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-82-LocPromptResp22.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-73-LocPromptResp33.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-44-LocPromptResp15.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-40-LocPromptResp28.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/.ipynb_checkpoints
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-71-HardPromptResp9.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-70-LocPromptResp25.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-73-LocPromptResp33.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-40-LocPromptResp28.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-71-HardPromptResp9.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-70-LocPromptResp25.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-43-LocPromptResp5.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-62-LocPromptResp8.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-84-LocPromptResp27.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-16-HardPromptResp7.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-63-LocPromptResp4.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-18-LocPromptResp1.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-33-HardPromptResp11.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-74-LocPromptResp35.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-23-LocPromptResp2.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-74-LocPromptResp35.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-45-LocPromptResp7.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-58-DialPromptResp13.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-80-LocPromptResp36.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-38-LocPromptResp3.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-63-LocPromptResp4.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-21-LocPromptResp21.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-42-ExpPromptResp3.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-33-HardPromptResp11.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-23-LocPromptResp2.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-60-HardPromptResp10.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-71-HardPromptResp9.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-82-LocPromptResp22.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-44-LocPromptResp15.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/53c7dbc41f259d6f7157d364-40-LocPromptResp28.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-70-LocPromptResp25.mp4
#
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-59-ExpPromptResp7.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-82-LocPromptResp22.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-73-LocPromptResp33.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-44-LocPromptResp15.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-84-LocPromptResp27.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-16-HardPromptResp7.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-60-HardPromptResp10.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-84-LocPromptResp27.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-20-ExpPromptResp8.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-16-HardPromptResp7.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-59-ExpPromptResp7.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-80-LocPromptResp36.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-51-DialPromptResp11.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-80-LocPromptResp36.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-77-LocPromptResp9.wav
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-74-LocPromptResp35.mp4
#
#
#  Input audio file too small or empty: /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio/53c7dbc41f259d6f7157d364-51-DialPromptResp11.mp4
#
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/ef360fc757c3a1d77fdf1b72-21-LocPromptResp21.wav
# Audio file converted successfully:
#  /Users/oishanibandopadhyay/Documents/Revising Honors Project/session-67d94e1a42f12a9364065df2-data/audio_wav/c3281b525f62d78af053c76e-21-LocPromptResp21.wav
